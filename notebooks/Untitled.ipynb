# %%
import os

# %%
def find_book(gener):
    if gener in os.listdir():
# Out:
# ['.ipynb_checkpoints',
#  '1.webp',
#  '108583494-c9396000-735f-11eb-8451-08d9dd72d624.png',
#  '1574404371_lesson5.zip',
#  '1574404784_lesson52.zip',
#  '1574404956_lesson61.zip',
#  '1574405426_lesson62.zip',
#  '1574406018_lesson71.zip',
#  '1574406430_lesson72.zip',
#  '1574412946_lesson8.zip',
#  '1574413358_lesson82.zip',
#  '1574413540_lesson91.zip',
#  '1574413716_lesson92.zip',
#  '1661925076115.png',
#  '1676875071880.jpg',
#  '1694983-note_taking_app.zip',
#  '18.3.Plotly.ipynb',
#  '18thSep-20220910T183302Z-001.zip',
#  '19.2.MySQL.7z',
#  '19.3 MongoDB.7z',
#  '1984949-proj_7(1)',
#  '1984949-proj_7(1).zip',
#  '1984949-proj_7.zip',
#  '1st Oct FSDS bootcamp-20221002T132848Z-001.zip',
#  '1_3MsFzl7zRZE3TihIC9JmaQ.png',
#  '2- Simple Linear Regression.pdf',
#  '2.jpg',
#  '2000355-case_study_(part_3).zip',
#  '2022-02-04.jpg',
#  '20th OctFSDS_bootcamp03. Google Play Store (Regression).zip',
#  '29th Jan FSDSBootcampR-20230204T075319Z-001.zip',
# ...
